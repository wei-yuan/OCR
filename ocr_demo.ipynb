# %% [markdown]
# # OCR Demo
# Author: Alex Hsu, Date: 2022/3/14
# ### Description
# This is an Optical Character Recognition (OCR) demonstration project using open source OCR engine [Tesseract](https://github.com/tesseract-ocr/tesseract#installing-tesseract)
#
# ### Reference
# Scene text recognition resources (including performance comparison and SOTA): https://github.com/HCIILAB/Scene-Text-Recognition

# %%
# import library
from PIL import Image
import cv2 
import pytesseract
from matplotlib import pyplot as plt

# %%
# the installation path of tesseract project
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

# %% [markdown]
# * Explanation of how tesseract model works: [Overview of the new neural network system in Tesseract 4.00](https://tesseract-ocr.github.io/tessdoc/tess4/NeuralNetsInTesseract4.00.html)
#
# * CRNN Model Literature Reference: Shi, Baoguang, Xiang Bai, and Cong Yao. "An end-to-end trainable neural network for image-based sequence recognition and its application to scene text recognition." IEEE transactions on pattern analysis and machine intelligence 39.11 (2016): 2298-2304.

# %%
# Read image from folder
# image source https://forkast.news/video-audio/bitcoin-value-fiat-binance-ceo-cz/
img_cv = cv2.imread(r'img/CZ-bio-card.jpg')

# %%
# By default OpenCV stores images in BGR format and since pytesseract assumes RGB format,
# we need to convert from BGR to RGB format/mode:
img_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.title('opencv image read')
plt.show()

# %%
# output OCR recognition result
print(pytesseract.image_to_string(img_rgb))
# Out:
# CHANGPENG ZHAO
# Co-Founder & CEO, Binance
# Asia
# Better known as CZ, Zhao is the founder of Binance, the world’s
#
# largest crypto exchange by trading volume
#
# Prior to Binance, Zhao was the head of development for
# Blockchain.com
#
# He was named to the 2020 Bloomberg 50 list of global icons
# and innovators
